# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with the APIs for Anthropic and Google, as well as OpenAI.

# %% [markdown]
# ## Setting up your keys
#
# If you haven't done so already, you could now create API keys for Anthropic and Google in addition to OpenAI.
#
# **Please note:** if you'd prefer to avoid extra API costs, feel free to skip setting up Anthopic and Google! You can see me do it, and focus on OpenAI for the course. You could also substitute Anthropic and/or Google for Ollama, using the exercise you did in week 1.
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://ai.google.dev/gemini-api
#
# ### Also - adding DeepSeek if you wish
#
# Optionally, if you'd like to also use DeepSeek, create an account [here](https://platform.deepseek.com/), create a key [here](https://platform.deepseek.com/api_keys) and top up with at least the minimum $2 [here](https://platform.deepseek.com/top_up).
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# ```
#
# Afterwards, you may need to restart the Jupyter Lab Kernel (the Python process that sits behind this notebook) via the Kernel menu, and then rerun the cells from the top.

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import anthropic
from IPython.display import Markdown, display, update_display
# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging

load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
# Out:
# OpenAI API Key exists and begins 4FzvrSQL

# %%
# Connect to OpenAI

client = OpenAI(
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    base_url="https://cx-test-foundry.openai.azure.com/openai/v1/",
)

# %% [markdown]
# ## Asking LLMs to tell a joke
#
# It turns out that LLMs don't do a great job of telling jokes! Let's compare a few models.
# Later we will be putting LLMs to better use!
#
# ### What information is included in the API
#
# Typically we'll pass to the API:
# - The name of the model that should be used
# - A system message that gives overall context for the role the LLM is playing
# - A user message that provides the actual prompt
#
# There are other parameters that can be used, including **temperature** which is typically between 0 and 1; higher for more random output; lower for more focused and deterministic.

# %%
system_message = "You are an assistant that is great at telling jokes"
user_prompt = "Tell a light-hearted joke for an audience of Data Scientists"

# %%
prompts = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_prompt}
  ]

# %%
# GPT-4o-mini
completion = client.chat.completions.create(
  model="grok-4-1-fast-reasoning", # Replace with your model deployment name.
  messages=prompts
)
print(completion.choices[0].message.content)
# Out:
# Why do data scientists mix up Halloween and Christmas?
#
# Because **Oct 31 = Dec 25**! 🎃🎄

# %%
challenge = [{"role": "system", "content": "You are a helpful assistant"},
             {"role": "user", "content": "How many words are there in your answer to this prompt"}]

# %%
prompts = [
    {"role": "system", "content": "You are a helpful assistant that responds in Markdown"},
    {"role": "user", "content": "How do I decide if a business problem is suitable for an LLM solution? Please respond in Markdown."}
  ]
completion = client.chat.completions.create(
  model="grok-4-1-fast-reasoning", # Replace with your model deployment name.
  messages=prompts
)
print(completion.choices[0].message.content)
# Out:
# # Deciding if a Business Problem is Suitable for an LLM Solution
#
# Large Language Models (LLMs) like GPT-4 or Llama are powerful for natural language tasks, but not every problem fits. Use this structured framework to evaluate suitability. It balances LLM strengths (e.g., text generation, summarization) against limitations (e.g., hallucinations, cost).
#
# ## Step 1: Understand the Problem
# - **Define the core task**: Is it classification, generation, extraction, reasoning, or something else?
# - **Identify inputs/outputs**: Are inputs primarily text? Outputs text-based?
# - **Assess constraints**: Accuracy needs? Real-time? Volume? Privacy?
#
# ## Step 2: Evaluate Against LLM Capabilities
# Use this **suitability checklist** (score 1-5 per criterion; aim for 20+ total for "suitable"):
#
# | Criterion | Description | LLM Fit (Why?) | Score (1-5) |
# |-----------|-------------|----------------|-------------|
# | **Text-Centric** | Involves unstructured text (e.g., emails, docs, chat)? | Excellent for NLP tasks like summarization, Q&A. | |
# | **Repetitive/Creative** | Manual, rule-heavy, or needs ideation (e.g., content creation)? | Automates boilerplate; generates ideas fast. | |
# | **Ambiguous/nuanced** | Handles context, tone, or variability? | Strong reasoning and pattern recognition. | |
# | **Scalable Volume** | High-volume but low-complexity per instance? | APIs scale easily; batch processing. | |
# | **Low Precision Needed** | "Good enough" outputs (e.g., drafts)? | Hallucinations tolerable with human review. | |
# | **Prototype Speed** | Quick to test? | No training data needed; prompt engineering suffices. | |
#
# **Total Score**: High (>20)? Green light. Medium (10-20)? Prototype first. Low (<10)? Explore alternatives.
#
# ## Step 3: Consider Trade-offs
# ### Pros of LLMs
# - **Rapid deployment**: Prompt → solution in hours.
# - **Flexibility**: Adapts to new tasks via few-shot learning.
# - **Cost-effective for prototypes**: Pay-per-use.
#
# ### Cons & Risks
# - **Hallucinations**: Fabricates facts; mitigate with RAG (Retrieval-Augmented Generation) or validation.
# - **Context limits**: ~128K tokens; chunk large inputs.
# - **Costs**: $0.01–$0.10 per 1K tokens; monitor for high-volume.
# - **Bias/Privacy**: Train/test for fairness; use on-prem models for sensitive data.
# - **Latency**: 1–10s per query; not ideal for real-time.
#
# | When **Suitable** | Examples |
# |-------------------|----------|
# | Customer support | Chatbots, ticket triage. |
# | Content ops | Summaries, marketing copy. |
# | Data analysis | Report generation from logs. |
# | Personalization | Email drafting, recommendations. |
#
# | When **NOT Suitable** | Alternatives |
# |-----------------------|--------------|
# | Precise math/finance | Spreadsheets, calculators, traditional ML. |
# | High-stakes accuracy (legal/medical) | Rule-based + human oversight. |
# | Images/video | Vision models (e.g., CLIP) or specialists. |
# | Real-time transactions | Databases, APIs. |
#
# ## Step 4: Validate with a Prototype
# 1. **Pick a small dataset** (10–100 examples).
# 2. **Prompt engineer**: Test variations.
# 3. **Measure metrics**: Accuracy, speed, cost (use tools like LangChain).
# 4. **A/B test**: Compare to status quo.
# 5. **ROI calculation**: (Value gained - Costs) / Time saved > 1?
#
# ## Final Tips
# - **Hybrid approach**: Combine LLMs with tools (e.g., APIs for facts, vector DBs for search).
# - **Iterate**: Start simple; fine-tune if needed.
# - **Monitor trends**: LLMs improve rapidly—re-evaluate yearly.
#
# If your problem scores high, dive in! Share details for tailored advice.

# %%
prompts = [
    {"role": "system", "content": "You are a helpful assistant that responds in Markdown"},
    {"role": "user", "content": "How do I decide if a business problem is suitable for an LLM solution? Please respond in Markdown."}
  ] 

def getClient(model="grok-4-1-fast-reasoning",messages=prompts):

    completion = client.chat.completions.create(
    model=model, # Replace with your model deployment name.
    messages=prompts
    )
    return completion

# %% [markdown]
# ## Back to OpenAI with a serious question

# %%
# To be serious! GPT-4o-mini with the original question

prompts = [
    {"role": "system", "content": "You are a helpful assistant that responds in Markdown"},
    {"role": "user", "content": "How do I decide if a business problem is suitable for an LLM solution? Please respond in Markdown."}
  ]

# %%
completion=getClient()
print(completion.choices[0].message.content)
# Out:
# # Deciding if a Business Problem is Suitable for an LLM Solution
#
# Large Language Models (LLMs) like GPT-4, Llama, or Claude excel at natural language tasks, reasoning, and pattern recognition, but they're not a silver bullet. Use this framework to evaluate suitability systematically.
#
# ## Step-by-Step Decision Framework
#
# 1. **Define the Problem Clearly**
#    - Articulate the core goal: What input does it take? What output is needed? What metrics define success (e.g., accuracy, speed, cost)?
#    - Example: "Summarize customer support tickets" vs. "Calculate real-time inventory levels."
#
# 2. **Assess LLM Strengths and Fit**
#    Use the table below to match your problem:
#
#    | LLM Strength                  | Suitable Problems                          | Unsuitable Problems                     |
#    |-------------------------------|--------------------------------------------|-----------------------------------------|
#    | **Text Generation & Summarization** | Content creation, report summaries, email drafting | High-precision math (use calculators)  |
#    | **Classification & Analysis** | Sentiment analysis, intent detection, topic categorization | Real-time sensor data processing       |
#    | **Q&A and Reasoning**         | Chatbots, knowledge retrieval, decision support | Tasks needing proprietary/confidential data access |
#    | **Creativity & Personalization** | Marketing copy, personalized recommendations | Regulated outputs (e.g., legal advice without oversight) |
#    | **Multimodal (with vision/audio)** | Image captioning, document parsing | Pure numerical simulations            |
#
# 3. **Evaluate Key Constraints**
#    - **Data Requirements**: Do you have labeled data for fine-tuning? LLMs shine in zero/few-shot scenarios but may hallucinate without grounding.
#    - **Accuracy & Reliability**: Tolerate ~5-20% error? Use RAG (Retrieval-Augmented Generation) or human-in-the-loop for critical tasks.
#    - **Latency & Scale**: Real-time (<1s)? Batch processing? LLMs can handle scale via APIs but watch token costs.
#    - **Cost**: Estimate tokens (input + output). Tools like OpenAI's tokenizer help. Compare to alternatives (e.g., rules-based systems).
#    - **Privacy/Security**: Sensitive data? Use on-premise models (e.g., Llama.cpp) or anonymization.
#    - **Hallucination Risk**: Ground with external data sources (e.g., vector DBs like Pinecone).
#
# 4. **Prototype and Test**
#    - Build a quick MVP using prompt engineering (e.g., via LangChain or Vercel AI SDK).
#    - Metrics: Precision/recall, human eval, A/B tests.
#    - Iterate: Chain-of-thought prompting, fine-tuning, or agents (e.g., ReAct) often boost performance.
#
# 5. **Calculate ROI**
#    - **Benefits**: Time savings, scalability, 24/7 automation.
#    - **Costs**: API fees (~$0.01-0.10 per 1K tokens), dev time, monitoring.
#    - Break-even: If it saves >20-50% human effort, it's promising.
#    - Hybrid Approach: LLM + rules/tools for best results.
#
# ## Common Red Flags (When NOT Suitable)
# - **High Precision Needed**: Financial transactions, diagnostics—use specialized ML or deterministic code.
# - **Real-Time/High-Volume Compute**: Edge devices—opt for lighter models or non-AI.
# - **Static/Rule-Based**: Simple if-then logic is cheaper/faster.
# - **No Language Component**: Pure image/video processing or simulations.
#
# ## Real-World Examples
# | Business Problem              | LLM Suitable? | Why? / Alternative                  |
# |-------------------------------|---------------|-------------------------------------|
# | Automate customer FAQs        | ✅ Yes       | Handles variations well; cheap.    |
# | Predict stock prices          | ❌ No        | Hallucinates; use time-series ML.  |
# | Generate personalized emails  | ✅ Yes       | Creative, scalable.                |
# | Audit compliance docs         | ⚠️ Maybe     | With RAG + human review.           |
#
# ## Final Recommendation
# **Start Small**: 80% of business problems have *some* LLM fit—prototype first. Tools like Hugging Face, Anthropic, or Azure OpenAI make it easy. If unsure, benchmark against baselines (humans, scripts). Reassess quarterly as LLMs evolve rapidly.
#
# For deeper dives, share your specific problem!
